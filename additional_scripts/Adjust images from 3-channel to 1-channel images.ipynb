# %%
from PIL import Image

# Open the RGB image
image = Image.open(r"D:\Gits\SAN\datasets\coco-middle_of_subtitle_empty\stuffthingmaps_detectron2\val2017\1875.png")

# Convert it to grayscale
gray_image = image.convert('L')

# Save the grayscale image
gray_image.save(r"D:\Gits\SAN\datasets\coco-middle_of_subtitle_empty\stuffthingmaps_detectron2\val2017\1875_grayscale_image.png")

# %%
import os
from PIL import Image

# Function to convert an image to grayscale
def convert_to_grayscale(input_path, output_path):
    image = Image.open(input_path)
    gray_image = image.convert('L')
    gray_image.save(output_path)

# Directory path to start the search
root_directory = r"D:\Gits\SAN\datasets\coco-active_speaker-overlapped\stuffthingmaps"

# Loop through all the files and subdirectories
for root, dirs, files in os.walk(root_directory):
    for file in files:
        # Check if the file is a jpg or png image
        if file.lower().endswith(('.jpg', '.png')):
            input_path = os.path.join(root, file)
            if file.lower().endswith('.jpg'):
                outputpath = input_path.replace(".jpg", ".png") 
            else:
                outputpath = input_path
            # output_path = os.path.join(root, f'grayscale_{file}')
            
            # Convert the image to grayscale
            convert_to_grayscale(input_path, outputpath)
            print(f'Converted {file} to grayscale.')

print('Conversion complete.')
# Out:
# Converted 0.jpg to grayscale.
# Converted 1.jpg to grayscale.
# Converted 10.jpg to grayscale.
# Converted 100.jpg to grayscale.
# Converted 1000.jpg to grayscale.
# Converted 1001.jpg to grayscale.
# Converted 1002.jpg to grayscale.
# Converted 1003.jpg to grayscale.
# Converted 1004.jpg to grayscale.
# Converted 1005.jpg to grayscale.
# Converted 1006.jpg to grayscale.
# Converted 1007.jpg to grayscale.
# Converted 1008.jpg to grayscale.
# Converted 1009.jpg to grayscale.
# Converted 101.jpg to grayscale.
# Converted 1010.jpg to grayscale.
# Converted 1011.jpg to grayscale.
# Converted 1012.jpg to grayscale.
# Converted 1013.jpg to grayscale.
# Converted 1014.jpg to grayscale.
# Converted 1015.jpg to grayscale.
# Converted 1016.jpg to grayscale.
# Converted 1017.jpg to grayscale.
# Converted 1018.jpg to grayscale.
# Converted 1019.jpg to grayscale.
# Converted 102.jpg to grayscale.
# Converted 1020.jpg to grayscale.
# Converted 1021.jpg to grayscale.
# ...
